# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunday-Okey/Pandas_Lesson_Colab/blob/main/Pandas_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##The Series object

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np

# %%
pd.Series()
# Out:
# <ipython-input-2-fa15c544da3b>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pd.Series()
# Series([], dtype: float64)

# %%
ice_cream_flavors = [
            "Chocolate",
            "Vanilla",
            "Strawberry",
            "Rum Raisin",
        ]
 
pd.Series(ice_cream_flavors)
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3    Rum Raisin
# dtype: object

# %%
pd.Series()

# %%
days_of_week = ["Monday", "Wednesday", "Friday", "Saturday"]

# %%
days_of_week = ["Monday", "Wednesday", "Wednesady", "Saturday"]

# %%
pd.Series(ice_cream_flavors, days_of_week)
# Out:
# Monday        Chocolate
# Wednesday       Vanilla
# Wednesady    Strawberry
# Saturday     Rum Raisin
# dtype: object

# %% [markdown]
# One additional advantage of keyword arguments is that they permit us to pass parameters in any order. By comparison, sequential/positional arguments require us to pass arguments in the order in which the constructor expects them. The next example swaps the order of the index and data keyword parameters. Pandas creates the same Series:

# %%
pd.Series(index=days_of_week, data= ice_cream_flavors)
# Out:
# Monday        Chocolate
# Wednesday       Vanilla
# Wednesady    Strawberry
# Saturday     Rum Raisin
# dtype: object

# %% [markdown]
# ###Creating a Series with missing values

# %%
temperatures = [94, 88, np.nan, 91]
pd.Series(data = temperatures)
# Out:
# 0    94.0
# 1    88.0
# 2     NaN
# 3    91.0
# dtype: float64

# %% [markdown]
# ###Creating a Series from Python objects

# %%
calorie_info = {
             "Cereal": 125,
             "Chocolate Bar": 406,
             "Ice Cream Sundae": 342,
         }
 
diet = pd.Series(calorie_info)
diet
# Out:
# Cereal              125
# Chocolate Bar       406
# Ice Cream Sundae    342
# dtype: int64

# %% [markdown]
# To create a Series that stores tuples, wrap the tuples in a list. Tuples work well for row values that consist of multiple parts or components, such as an address:

# %%
rgb_colors = [(120, 41, 26), (196, 165, 45)]
pd.Series(data = rgb_colors)
# Out:
# 0     (120, 41, 26)
# 1    (196, 165, 45)
# dtype: object

# %% [markdown]
# The Series constructor’s data parameter also accepts a NumPy ndarray object. Many data science libraries use NumPy arrays, which are common storage formats for moving data around. The next example feeds the Series constructor an ndarray generated by NumPy’s randint function

# %%
random_data = np.random.randint(1, 101, 10)
random_data
# Out:
# array([37, 68, 14, 65, 82, 10, 80, 32, 47, 61])

# %%
pd.Series(random_data)
# Out:
# 0    37
# 1    68
# 2    14
# 3    65
# 4    82
# 5    10
# 6    80
# 7    32
# 8    47
# 9    61
# dtype: int64

# %% [markdown]
#  ### Series attributes

# %%
diets = {'Cereal': 125,
'Chocolate Bar': 406,
'Ice Cream Sundae': 342}

# %%
diets = pd.Series(diets)

# %%
type(diets.values)
# Out:
# numpy.ndarray

# %%
type(diets.index)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# Some attributes reveal helpful details about the object. dtype, for example, returns the data type of the Series’ values:

# %%
diets.dtype
# Out:
# dtype('int64')

# %% [markdown]
# The size attribute returns the number of values in the Series

# %%
diets.size
# Out:
# 3

# %% [markdown]
# The complementary shape attribute returns a tuple with the dimensions of a pandas data structure.

# %%
diets.shape
# Out:
# (3,)

# %% [markdown]
# The is_unique attribute returns True if all Series values are unique:

# %%
diets.is_unique
# Out:
# True

# %% [markdown]
# The is_monotonic attribute returns True if each Series value is greater than the previous one. The increments between values do not have to be equal:

# %%
diets.is_monotonic
# Out:
# False

# %% [markdown]
# ### Retrieving the first and last rows

# %%
values = range(0, 500, 5)
nums = pd.Series(data = values)
nums
# Out:
# 0       0
# 1       5
# 2      10
# 3      15
# 4      20
#      ...
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# Length: 100, dtype: int64

# %%
nums.head()
# Out:
# 0     0
# 1     5
# 2    10
# 3    15
# 4    20
# dtype: int64

# %%
nums.tail()
# Out:
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# dtype: int64

# %%
numbers = pd.Series([1, 2, 3, np.nan, 4, 5])
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.count()
# Out:
# 5

# %%
numbers.sum()
# Out:
# 15.0

# %%
numbers.sum(skipna=False)
# Out:
# nan

# %%
numbers.product()
# Out:
# 120.0

# %%
numbers.cumsum()
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    10.0
# 5    15.0
# dtype: float64

# %%
numbers.cumsum(skipna = False)
# Out:
# 0    1.0
# 1    3.0
# 2    6.0
# 3    NaN
# 4    NaN
# 5    NaN
# dtype: float64

# %%
authors = pd.Series(
             ["Hemingway", "Orwell", "Dostoevsky", "Fitzgerald", "Orwell"]
         )

# %%
authors.unique()
# Out:
# array(['Hemingway', 'Orwell', 'Dostoevsky', 'Fitzgerald'], dtype=object)

# %%
authors.nunique()
# Out:
# 4

# %% [markdown]
# ##Coding challenge

# %% [markdown]
# Suppose that you’re given these two data structures:

# %%
superheroes = [
             "Batman",
             "Superman",
             "Spider-Man",
             "Iron Man",
             "Captain America",
             "Wonder Woman"
         ]
strength_levels = (100, 120, 90, 95, 110, 120)

# %% [markdown]
# Here are your challenges:
#
# 1. Use the list of superheroes to populate a new Series object.
#
# 2. Use the tuple of strengths to populate a new Series object.
#
# 3. Create a Series with the superheroes as index labels and the strength levels as the values. Assign the Series to a heroes variable.
#
# 4. Extract the first two rows of the heroes Series.
#
# 5. Extract the last four rows of the heroes Series.
#
# 6. Determine the number of unique values in your heroes Series.
#
# 7. Calculate the average strength of the superheroes in heroes.
#
# 8. Calculate the maximum and minimum strengths in heroes.
#
# 9. Calculate what each superhero’s strength level would be if it doubled.
#
# 10. Convert the heroes Series to a Python dictionary.

# %%
series_1 = pd.Series(superheroes)
series_1
# Out:
# 0             Batman
# 1           Superman
# 2         Spider-Man
# 3           Iron Man
# 4    Captain America
# 5       Wonder Woman
# dtype: object

# %%
series_2 = pd.Series(strength_levels)
series_2
# Out:
# 0    100
# 1    120
# 2     90
# 3     95
# 4    110
# 5    120
# dtype: int64

# %%
heroes = pd.Series(data = strength_levels, index=superheroes)
heroes
# Out:
# Batman             100
# Superman           120
# Spider-Man          90
# Iron Man            95
# Captain America    110
# Wonder Woman       120
# dtype: int64

# %%
heroes.head(2)
# Out:
# Batman      100
# Superman    120
# dtype: int64

# %%
heroes.tail(4)
# Out:
# Spider-Man          90
# Iron Man            95
# Captain America    110
# Wonder Woman       120
# dtype: int64

# %%
heroes.nunique()
# Out:
# 5

# %%
heroes.mean()
# Out:
# 105.83333333333333

# %%
heroes.min()
# Out:
# 90

# %%
heroes.max()
# Out:
# 120

# %%
heroes.mul(2)
# Out:
# Batman             200
# Superman           240
# Spider-Man         180
# Iron Man           190
# Captain America    220
# Wonder Woman       240
# dtype: int64

# %%
dict(heroes)
# Out:
# {'Batman': 100,
#  'Superman': 120,
#  'Spider-Man': 90,
#  'Iron Man': 95,
#  'Captain America': 110,
#  'Wonder Woman': 120}

# %% [markdown]
# A Series is a one-dimensional homogeneous labeled array that holds values and an index.
#
# A Series’ values can be of any data type. The index labels can be of any immutable data type.
#
# Pandas assigns both an index position and an index label to each Series value.
#
# We can populate a Series with data from lists, dictionaries, tuples, NumPy arrays, and more.
#
# A Series plays friendly with Python’s built-in functions, including dict, list, and len.
