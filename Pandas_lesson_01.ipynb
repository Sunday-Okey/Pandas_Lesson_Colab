# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunday-Okey/Pandas_Lesson_Colab/blob/main/Pandas_lesson_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A Tour of Pandas Library

# %% [markdown]
# ![image.png](data:image/png;base64,...)
